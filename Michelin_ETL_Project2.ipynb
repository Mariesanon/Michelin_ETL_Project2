# %%
# install psycopg2
# !pip install psycopg2-binary
# Out:
# Requirement already satisfied: psycopg2-binary in c:\users\mjrafol\anaconda3\envs\pythondata\lib\site-packages (2.9.3)

# %%
# import the dependencies
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ## Step 1: Extract

# %% [markdown]
# #### (1.a) Extract the First Data Source: 2021 Michelin Star Restaurant

# %%
# import a csv file (extract)
csv_file = "Resources/restaurants/michelin_my_maps.csv"
main_df = pd.read_csv(csv_file, dtype={"PhoneNumber": "str"})
main_df.head()
# Out:
#                                      Name  \
# 0                                    Aqua
# 1                 The Table Kevin Fehling
# 2  Restaurant Überfahrt Christian Jürgens
# 3   Victor's Fine Dining by christian bau
# 4                                    Rutz
#
#                                              Address       Location MinPrice  \
# 0            Parkstraße 1, Wolfsburg, 38440, Germany      Wolfsburg      225
# 1          Shanghaiallee 15, Hamburg, 20457, Germany        Hamburg      230
# 2  Überfahrtstraße 10, Rottach-Egern, 83700, Germany  Rottach-Egern      259
# 3             Schlossstraße 27, Perl, 66706, Germany           Perl      205
# 4           Chausseestraße 8, Berlin, 10115, Germany         Berlin      198
#
#   MaxPrice Currency                   Cuisine  Longitude   Latitude  \
# 0      225      EUR  Creative, Modern Cuisine  10.789999  52.433172
# 1      230      EUR                  Creative  10.002980  53.542623
# 2      319      EUR                  Creative  11.758229  47.696685
# 3      295      EUR                  Creative   6.387211  49.535173
# 4      245      EUR  Modern Cuisine, Creative  13.386087  52.528351
#
#      PhoneNumber                                                Url  \
# 0  +495361606056  https://guide.michelin.com/en/niedersachsen/wo...
# 1  +494022867422  https://guide.michelin.com/en/hamburg-region/h...
# 2    +4980226690  https://guide.michelin.com/en/bayern/rottach-e...
# 3   +49686679118  https://guide.michelin.com/en/saarland/perl/re...
# 4  +493024628760  https://guide.michelin.com/en/berlin-region/be...
#
#                             WebsiteUrl             Award
# 0       http://www.restaurant-aqua.com  3 MICHELIN Stars
# 1     http://www.the-table-hamburg.de/  3 MICHELIN Stars
# 2     http://www.althoffcollection.com  3 MICHELIN Stars
# 3  https://www.victors-fine-dining.de/  3 MICHELIN Stars
# 4      https://www.rutz-restaurant.de/  3 MICHELIN Stars

# %%
# clean up with relevant columns and return only the USA restaurants (transform)
all_resto = main_df[['Name', 'Address', 'Location','PhoneNumber','WebsiteUrl','Award','Currency']].copy()
usa_resto = all_resto.loc[(all_resto['Currency'] == 'USD')]
usa_resto.head()
# Out:
#                   Name                                            Address  \
# 77  The French Laundry  6640 Washington St., Yountville, 94599, United...
# 78        SingleThread    131 North St., Healdsburg, 95448, United States
# 79             Manresa   320 Village Ln., Los Gatos, 95030, United States
# 80       Atelier Crenn  3127 Fillmore St., San Francisco, 94123, Unite...
# 81                Benu  22 Hawthorne St., San Francisco, 94105, United...
#
#          Location   PhoneNumber                          WebsiteUrl  \
# 77     Yountville  +17079442380    https://www.thomaskeller.com/tfl
# 78     Healdsburg  +17077234646  https://www.singlethreadfarms.com/
# 79      Los Gatos  +14083544330  https://www.manresarestaurant.com/
# 80  San Francisco  +14154400460       https://www.ateliercrenn.com/
# 81  San Francisco  +14156854860             https://www.benusf.com/
#
#                Award Currency
# 77  3 MICHELIN Stars      USD
# 78  3 MICHELIN Stars      USD
# 79  3 MICHELIN Stars      USD
# 80  3 MICHELIN Stars      USD
# 81  3 MICHELIN Stars      USD

# %% [markdown]
# #### (1.b) Extract the Second Data Source: Price Range

# %%
# import a csv file (extract) - one-star-michelin
one_csv_file = "Resources/price_range/one-star-michelin-restaurants.csv"
one_star = pd.read_csv(one_csv_file, dtype={"price": "str"})
one_star.head()
# Out:
#             name  year   latitude  longitude            city   region zipCode  \
# 0   Kilian Stuba  2019  47.348580   10.17114  Kleinwalsertal  Austria   87568
# 1  Pfefferschiff  2019  47.837870   13.07917        Hallwang  Austria    5300
# 2      Esszimmer  2019  47.806850   13.03409        Salzburg  Austria    5020
# 3     Carpe Diem  2019  47.800010   13.04006        Salzburg  Austria    5020
# 4         Edvard  2019  48.216503   16.36852            Wien  Austria    1010
#
#            cuisine  price                                                url
# 0         Creative  $$$$$  https://guide.michelin.com/at/en/vorarlberg/kl...
# 1  Classic cuisine  $$$$$  https://guide.michelin.com/at/en/salzburg-regi...
# 2         Creative  $$$$$  https://guide.michelin.com/at/en/salzburg-regi...
# 3   Market cuisine  $$$$$  https://guide.michelin.com/at/en/salzburg-regi...
# 4   Modern cuisine   $$$$  https://guide.michelin.com/at/en/vienna/wien/r...

# %%
# check the datatype of one-star-michelin
one_star.dtypes
# Out:
# name          object
# year           int64
# latitude     float64
# longitude    float64
# city          object
# region        object
# zipCode       object
# cuisine       object
# price         object
# url           object
# dtype: object

# %%
# import a csv file (extract) - two-star-michelin
two_csv_file = "Resources/price_range/two-stars-michelin-restaurants.csv"
two_star = pd.read_csv(two_csv_file, dtype={"price": "str"})
two_star
# Out:
#                                     name  year  latitude  longitude  \
# 0                       SENNS.Restaurant  2019  47.83636  13.063890
# 1                                 Ikarus  2019  47.79536  13.006950
# 2                            Mraz & Sohn  2019  48.23129  16.376370
# 3                    Konstantin Filippou  2019  48.21056  16.379960
# 4       Silvio Nickol Gourmet Restaurant  2019  48.20558  16.376930
# ..                                   ...   ...       ...        ...
# 105          Dinner by Heston Blumenthal  2019  51.50208  -0.160110
# 106                                  Umu  2019  51.51130  -0.144550
# 107  Sketch (The Lecture Room & Library)  2019  51.51287  -0.141360
# 108                           Greenhouse  2019  51.50769  -0.149260
# 109              Claude Bosi at Bibendum  2019  51.49341  -0.169089
#
#           city          region   zipCode              cuisine  price  \
# 0     Salzburg         Austria      5020             Creative  $$$$$
# 1     Salzburg         Austria      5020             Creative  $$$$$
# 2         Wien         Austria      1200             Creative  $$$$$
# 3         Wien         Austria      1010       Modern cuisine  $$$$$
# 4         Wien         Austria      1010       Modern cuisine  $$$$$
# ..         ...             ...       ...                  ...    ...
# 105  Hyde Park  United Kingdom  SW1X 7LA  Traditional British    NaN
# 106    Mayfair  United Kingdom   W1J 6LX             Japanese    NaN
# 107    Mayfair  United Kingdom   W1S 2XG        Modern French    NaN
# 108    Mayfair  United Kingdom   W1J 5NY             Creative    NaN
# 109    Chelsea  United Kingdom   SW3 6RD               French    NaN
#
#                                                    url
# 0    https://guide.michelin.com/at/en/salzburg-regi...
# 1    https://guide.michelin.com/at/en/salzburg-regi...
# 2    https://guide.michelin.com/at/en/vienna/wien/r...
# 3    https://guide.michelin.com/at/en/vienna/wien/r...
# 4    https://guide.michelin.com/at/en/vienna/wien/r...
# ..                                                 ...
# 105  https://guide.michelin.com/gb/en/greater-londo...
# 106  https://guide.michelin.com/gb/en/greater-londo...
# 107  https://guide.michelin.com/gb/en/greater-londo...
# 108  https://guide.michelin.com/gb/en/greater-londo...
# 109  https://guide.michelin.com/gb/en/greater-londo...
#
# [110 rows x 10 columns]

# %%
# check the datatype of two-star-michelin
two_star.dtypes
# Out:
# name          object
# year           int64
# latitude     float64
# longitude    float64
# city          object
# region        object
# zipCode       object
# cuisine       object
# price         object
# url           object
# dtype: object

# %%
w = lambda x: (x.replace('$$$$$','TEST') if x=='$$$$$' else 'TEST@')

# %%
# import a csv file (extract) - three-star-michelin
three_csv_file = "Resources/price_range/three-stars-michelin-restaurants.csv"
three_star = pd.read_csv(three_csv_file, converters={"price":w})
three_star.head()
# Out:
#             name  year  latitude  longitude                 city      region  \
# 0         Amador  2019  48.25406   16.35915                 Wien     Austria
# 1        Manresa  2019  37.22761 -121.98071  South San Francisco  California
# 2           Benu  2019  37.78521 -122.39876        San Francisco  California
# 3         Quince  2019  37.79762 -122.40337        San Francisco  California
# 4  Atelier Crenn  2019  37.79835 -122.43586        San Francisco  California
#
#   zipCode       cuisine  price  \
# 0    1190      Creative   TEST
# 1   95030  Contemporary  TEST@
# 2   94105         Asian  TEST@
# 3   94133  Contemporary  TEST@
# 4   94123  Contemporary  TEST@
#
#                                                  url
# 0  https://guide.michelin.com/at/en/vienna/wien/r...
# 1  https://guide.michelin.com/us/en/california/so...
# 2  https://guide.michelin.com/us/en/california/sa...
# 3  https://guide.michelin.com/us/en/california/sa...
# 4  https://guide.michelin.com/us/en/california/sa...

# %%
# check the datatype of three-star-michelin
three_star.dtypes
# Out:
# name          object
# year           int64
# latitude     float64
# longitude    float64
# city          object
# region        object
# zipCode       object
# cuisine       object
# price         object
# url           object
# dtype: object

# %%
# consolidate all three files (one-star, two-star and three-star)
appended_file = one_star.append([two_star, three_star])
appended_file.head()
# Out:
#             name  year   latitude  longitude            city   region zipCode  \
# 0   Kilian Stuba  2019  47.348580   10.17114  Kleinwalsertal  Austria   87568
# 1  Pfefferschiff  2019  47.837870   13.07917        Hallwang  Austria    5300
# 2      Esszimmer  2019  47.806850   13.03409        Salzburg  Austria    5020
# 3     Carpe Diem  2019  47.800010   13.04006        Salzburg  Austria    5020
# 4         Edvard  2019  48.216503   16.36852            Wien  Austria    1010
#
#            cuisine  price                                                url
# 0         Creative  $$$$$  https://guide.michelin.com/at/en/vorarlberg/kl...
# 1  Classic cuisine  $$$$$  https://guide.michelin.com/at/en/salzburg-regi...
# 2         Creative  $$$$$  https://guide.michelin.com/at/en/salzburg-regi...
# 3   Market cuisine  $$$$$  https://guide.michelin.com/at/en/salzburg-regi...
# 4   Modern cuisine   $$$$  https://guide.michelin.com/at/en/vienna/wien/r...

# %%
# clean up with relevant columns and return only the relevant fields (transform)
michelin_2021 = appended_file[['name', 'region', 'cuisine','price']].copy()
michelin_2021.head()
# Out:
#             name   region          cuisine  price
# 0   Kilian Stuba  Austria         Creative  $$$$$
# 1  Pfefferschiff  Austria  Classic cuisine  $$$$$
# 2      Esszimmer  Austria         Creative  $$$$$
# 3     Carpe Diem  Austria   Market cuisine  $$$$$
# 4         Edvard  Austria   Modern cuisine   $$$$

# %%
# clean up the casing of the key "name" (transform)
michelin_2021_renamed = michelin_2021.rename(columns={"name" :"Name",
                                                     "region":"Region",
                                                     "cuisine":"Cuisine",
                                                     "price":"Price Range"})
michelin_2021_renamed.head()
# Out:
#             Name   Region          Cuisine Price Range
# 0   Kilian Stuba  Austria         Creative       $$$$$
# 1  Pfefferschiff  Austria  Classic cuisine       $$$$$
# 2      Esszimmer  Austria         Creative       $$$$$
# 3     Carpe Diem  Austria   Market cuisine       $$$$$
# 4         Edvard  Austria   Modern cuisine        $$$$

# %%
merge = pd.merge(usa_resto, michelin_2021_renamed, on = "Name", how = 'left')
merge = pd.merge(usa_resto, michelin_2021_renamed, on = "Name", how = 'left')

merge
# Out:
#                      Name                                            Address  \
# 0      The French Laundry  6640 Washington St., Yountville, 94599, United...
# 1            SingleThread    131 North St., Healdsburg, 95448, United States
# 2                 Manresa   320 Village Ln., Los Gatos, 95030, United States
# 3           Atelier Crenn  3127 Fillmore St., San Francisco, 94123, Unite...
# 4                    Benu  22 Hawthorne St., San Francisco, 94105, United...
# ..                    ...                                                ...
# 566       Queen’s English  3410 11th St. NW, Washington, 20010, United St...
# 567  Residents Cafe & Bar  1306 18th St. NW, Washington, 20036, United St...
# 568                 Makan  3400 11th St. NW, Washington, 20010, United St...
# 569                  Ellē  3221 Mt. Pleasant St. NW, Washington, 20010, U...
# 570   Karma Modern Indian     611 I St. NW, Washington, 20001, United States
#
#           Location   PhoneNumber                          WebsiteUrl  \
# 0       Yountville  +17079442380    https://www.thomaskeller.com/tfl
# 1       Healdsburg  +17077234646  https://www.singlethreadfarms.com/
# 2        Los Gatos  +14083544330  https://www.manresarestaurant.com/
# 3    San Francisco  +14154400460       https://www.ateliercrenn.com/
# 4    San Francisco  +14156854860             https://www.benusf.com/
# ..             ...           ...                                 ...
# 566     Washington           NaN    https://www.queensenglishdc.com/
# 567     Washington  +12026029563        https://www.residentsdc.com/
# 568     Washington  +12027302295  https://www.makanrestaurantdc.com/
# 569     Washington  +12026520040          https://www.eatatelle.com/
# 570     Washington  +12028980393  https://www.karmamodernindian.com/
#
#                 Award Currency      Region       Cuisine Price Range
# 0    3 MICHELIN Stars      USD  California  Contemporary        $$$$
# 1    3 MICHELIN Stars      USD  California  Contemporary        $$$$
# 2    3 MICHELIN Stars      USD  California  Contemporary        $$$$
# 3    3 MICHELIN Stars      USD  California  Contemporary        $$$$
# 4    3 MICHELIN Stars      USD  California         Asian        $$$$
# ..                ...      ...         ...           ...         ...
# 566      Bib Gourmand      USD         NaN           NaN         NaN
# 567      Bib Gourmand      USD         NaN           NaN         NaN
# 568      Bib Gourmand      USD         NaN           NaN         NaN
# 569      Bib Gourmand      USD         NaN           NaN         NaN
# 570      Bib Gourmand      USD         NaN           NaN         NaN
#
# [571 rows x 10 columns]

# %%
test = usa_resto.loc[(usa_resto['Name'] == "The French Laundry")]
test
# Out:
#                   Name                                            Address  \
# 77  The French Laundry  6640 Washington St., Yountville, 94599, United...
#
#       Location   PhoneNumber                        WebsiteUrl  \
# 77  Yountville  +17079442380  https://www.thomaskeller.com/tfl
#
#                Award Currency
# 77  3 MICHELIN Stars      USD

# %%
test = michelin_2021_renamed.loc[(michelin_2021_renamed['Name'] == "The French Laundry")]
test
# Out:
#                  Name      Region       Cuisine Price Range
# 5  The French Laundry  California  Contemporary        $$$$

# %%
test = three_star.loc[(three_star['name'] == "The French Laundry")]
test
# Out:
#                  name  year  latitude  longitude           city      region  \
# 5  The French Laundry  2019  38.40443 -122.36474  San Francisco  California
#
#   zipCode       cuisine price  \
# 5   94599  Contemporary  $$$$
#
#                                                  url
# 5  https://guide.michelin.com/us/en/california/sa...
